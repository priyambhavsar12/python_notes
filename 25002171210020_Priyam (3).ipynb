# %%
a = 10
b = 15
print(a+b)
# Out:
# 25

# %%
print(a-b)
# Out:
# -5

# %%
print(a*b)
# Out:
# 150

# %%
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
print(a*b)
# Out:
# 150

# %% [markdown]
# ### Chapter - 1 :
# kw list is a list of ***keywords***of python

# %% [raw]
# a = 21
# b = 48
# print(a+b)

# %% [markdown]
# #### Indentifiers
# ##### Rules
# 1> The only allowed characters in python are:
# - alphabet symbols(upper or lower case)
# - digits (0 to 9)
# - underscore symbol(_)

# %%
cash = 100

# %% [markdown]
# ca$h = 100  not allowed

# %% [markdown]
# 2> identifiers should not start with digit
# abc123 = 50 is allowed
#  X  123abc = 50 not allowed

# %% [markdown]
# 3> identifiers are case sensitive
# Total = 50
# TOTAL = 100
# total = 150

# %% [markdown]
# 4> We can not use reserved keywords as identifiers
# like :  if , for , etc.

# %% [markdown]
# 5> There is no length limit for identifiers but not recommended to use lenghty names

# %% [markdown]
# 6> if identifiers starts with underscore( _ ) then it indicate it is private

# %% [markdown]
# 7> if identifiers starts with double underscore ( __ ) then it is strongly private

# %% [markdown]
# 8> if identifiers starts and ends with two underscores symbols then it is language defined special naem which is also known as
# magic methods
# __add__
# __del__

# %%
'code'.isidentifier()
# Out:
# True

# %%
'ca$h' .isidentifier()
# Out:
# False

# %% [markdown]
# ### Data Types :
# - Text type : str
# - Numeric Type : int,float
# - Sequence Type : list,tuple,range
# - Mapping Type : dict
# - Set Type : set, frozenset
# - Boolean Type : bool

# %%
a = 10 
b =50505050050505
c = 2.5
d = 'D'
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
l = [1,2,3,4,5]
t = (1,2,3,4)
r = range(1,10,2)
print(type(l))
print(type(t))
print(type(r))
print(r)
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'range'>
# range(1, 10, 2)

# %%
d = {1 : 'X', 2 : 'Y'}
print(type(d))
print(d)
# Out:
# <class 'dict'>
# {1: 'X', 2: 'Y'}

# %%
s = {1,2,3,4,5}
print(type(s))
# Out:
# <class 'set'>

# %% [markdown]
# ### binary representation

# %%
c = 0b1010
print(c)
# Out:
# 10

# %% [markdown]
# ### octal representation

# %%
c = 0o127
print(c)
# Out:
# 87

# %% [markdown]
# ### hexadecimal reprensentation

# %%
c= 0x2134
print(c)
# Out:
# 8500

# %% [markdown]
# ##### binary conversion

# %%
bin(15)
bin(0o11)
# Out:
# '0b1001'

# %%
bin(0x10)
# Out:
# '0b10000'

# %%
oct(12)
# Out:
# '0o14'

# %%
oct(0b1111)
# Out:
# '0o17'

# %% [markdown]
# ##### hexadecimal conversion

# %%
hex(100)
# Out:
# '0x64'

# %%
hex(0b111111)
# Out:
# '0x3f'

# %%
hex(0o12345)
# Out:
# '0x14e5'

# %%
a =36.5
b = 36000
c = 36e3
print(b)
print(c)
# Out:
# 36000
# 36000.0

# %% [markdown]
# 36e3 is same as 36000 but e3 gives float value

# %% [markdown]
# ## Sequence Type -> list,tuple , range

# %%
l1 = [1,2,3,4,5,5]
l2 = ["Priyam","Virat",4.9,2000]
l3 = [True,False]
print(l1)
print(l2)
l1[2] = 12
print(l1)
# Out:
# [1, 2, 3, 4, 5, 5]
# ['Priyam', 'Virat', 4.9, 2000]
# [1, 2, 12, 4, 5, 5]

# %% [markdown]
# This is list , a data structure which is mutable and can contain heterogeneous data at same time

# %%
s1 = {1,2,3,4,5}
print(s1)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(type(s1))
# Out:
# <class 'set'>

# %%
t1 = (1,2,3,4,5)
print(t1)
print(type(t1))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
t1 = (1,2,3,44,555,4,5,3)
print(t1)
# Out:
# (1, 2, 3, 44, 555, 4, 5, 3)

# %% [markdown]
# tuple cant assign on basis of index like list, whereas list can assign values on index basis

# %% [markdown]
# range(X) -> give numbers from 0 to X-1
# range(start,end,step)
# range(end)
# range(start,end)

# %%
x = range(5)
print(list(x)) #for printing range must type cast in list
print(type(x))
# Out:
# [0, 1, 2, 3, 4]
# <class 'range'>

# %% [markdown]
# ### Looping using range

# %%
for i in range(5):
    print("Hello")
    print(i)
# Out:
# Hello
# 0
# Hello
# 1
# Hello
# 2
# Hello
# 3
# Hello
# 4

# %%
for i in range(1,15,3):
    print(i)
# Out:
# 1
# 4
# 7
# 10
# 13

# %% [markdown]
# #### Mapping Type -> dict

# %%
d = {12: "Priyam",18:"Virat"}
print(d)
print(type(d))
print(d[12])
print(d[18])
# Out:
# {12: 'Priyam', 18: 'Virat'}
# <class 'dict'>
# Priyam
# Virat

# %% [markdown]
# ### Set Type -> set,frozenset

# %%
s = {1,2,2,3,4,5,65,6,78,8}
print(s)
print(type(s))
# Out:
# {1, 2, 3, 4, 5, 65, 6, 8, 78}
# <class 'set'>

# %%
l = {"apple","banana","papaya","apple"}
print(l)
# Out:
# {'banana', 'papaya', 'apple'}

# %% [markdown]
# Set is unordered and indexing can't be used and duplication is not allowed

# %%
f= frozenset(l)
print(f)
print(type(f))
# Out:
# frozenset({'banana', 'papaya', 'apple'})
# <class 'frozenset'>

# %% [markdown]
# #### Boolean Type -> (bool)

# %%
print(20>3)
print(20==8)
print(bool("abc"))
print(bool(""))
print(bool(123))
print(bool([1,2,3,4]))
print(bool(False))
print(bool(0))
print(bool(True))
print(bool("False"))
print(bool(1))
# Out:
# True
# False
# True
# False
# True
# True
# False
# False
# True
# True
# True

# %%
x = 1,2,3,4
print(x)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# ### Global And Local Variable

# %%
a = "Python" # global 
def demo():
    global a
    a = "Java" # local
    print(a)
demo()
print(a)
# Out:
# Java
# Java

# %%
# Read input from users
s = int(input("Enter value of s:"))
print(s)
print(type(s))
# Out:
# Enter value of s: 5
# 5
# <class 'int'>

# %%
a = int(input("enter a:"))
b = int(input("enter b:"))
c= a+b
print(c)
# Out:
# enter a: 1
# enter b: 2
# 3

# %%
#area of triangle
base = float(input("enter base:"))
height = float(input("enter height:"))
area = 0.5*base*height
print(area)
# Out:
# enter base: 1
# enter height: 2
# 1.0

# %% [markdown]
# ### Type Casting

# %% [markdown]
# 1> int

# %%
int(123.978)
int(True)
int(False)
# Out:
# 0

# %% [markdown]
# 2> float

# %%
float(100)
float(True)
float(False)
float("10")
# Out:
# 10.0

# %% [markdown]
# 3> bool,
# 4> string

# %%
str(10)
str(10.5)
str(True)
# Out:
# 'True'

# %%
# ord() and chr() function

ord('A')  #gives ask value for char
ord('$')

chr(97)  # gives char for ask value
chr(120)
# Out:
# 'x'

# %% [markdown]
# #### Operators

# %% [markdown]
# ##### 1. Arithmetic Operator

# %%
x = "python "
print(x*2)
# Out:
# python python

# %%
a = 15
b= 2
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# 17
# 13
# 30
# 7.5
# 1
# 7
# 225

# %% [markdown]
# ![image.png](attachment:43359030-87c7-4196-8e61-c4649e8216a0.png)

# %% [markdown]
# ##### 2. Comparison Operators

# %% [markdown]
# ![image.png](attachment:3315da89-a2ee-4fda-b80e-4b25af309113.png)

# %%
10<20<30>40<50
# Out:
# False

# %% [markdown]
# ##### 3. Logical Operators

# %% [markdown]
# 1)boolean type
#
# and -> if both arguements are true then result is true ;
# or -> if atleast one arguement is true then result is true;
# not -> it is complement
#
#
#
# 2) non boolean type
#
#
# X and Y -> if X is evaluates to False return X otherwise return Y;
# X or Y -> if X is evaluates to True then return X otherwise return Y ;
# not X -> if X is evaluates to False then result is True otherwise False;

# %%
10 and 20 
#10 or 20 
#not 10 
not 0
0 or 20
# Out:
# 20

# %% [markdown]
# #### Ternary Operator (Conditional)
# Syntax:
# X = first value if condition else second value

# %%
a =10
b =20
x = 30 if a>b else 40
print(x)
# Out:
# 40

# %% [markdown]
# #### Assignment Operator

# %% [markdown]
# ![image.png](attachment:4ead77de-7a99-452e-9fd9-8e0efa8402b3.png)

# %% [markdown]
# #### Membership Operator
#
# 1. in
#
# 2. not in

# %%
a = "Python is very easy"
print("I" in a)
print("I" not in a)
print("y" in a)
# Out:
# False
# True
# True

# %%
l= [5,21,3,4,65,78,98,67]
print(5 in l)
# Out:
# True

# %% [markdown]
# ### MAth module

# %%
import math as m
dir(math)
math.factorial(5)
math.sqrt(144)
m.sqrt(16)
from math import *
sqrt(144)
# Out:
# 12.0

# %%
factorial(5)
pow(5,2)
print(m.pi)
floor(3.9)
# Out:
# 3.141592653589793
# 3

# %% [markdown]
# ![image.png](attachment:c2267614-776b-4392-a831-b2885c476441.png)

# %%
4*3/6*7+3
# Out:
# 17.0

# %%
5**3**1*5/True
# Out:
# 625.0

# %%
print("1" in "123" and "False" or True)
# Out:
# False

# %%
print(7*5**2/True*False)
# Out:
# 0.0

# %%
# W. A. P . to convert the temperature from fahrenheit to celsius and vice versa

C1 = float(input("enter temp in C:"))
F1= ((9/5)*C1)+32
print(F1)

F2 = float(input("enter temp in F:"))
C2 = (F2-32)*(5/9)
print(C2)
# Out:
# enter temp in C: 25
# 77.0
# enter temp in F: 98
# 36.66666666666667

# %%
a = float(input("enter amount:"))
c2000= a//2000
c500 = (a%2000)//500
c200 = (a%2000%500)//200
c100 = (a%2000%500%200)//100
c50 =  (a%2000%500%200%100)//50
c20 = (a%2000%500%200%100%50)//20
c10 = (a%2000%500%200%100%50%20)//10

print(c2000,c500,c200,c100,c50,c20,c10)
# Out:
# enter amount: 1340
# 0.0 2.0 1.0 1.0 0.0 2.0 0.0

# %% [markdown]
# ## Unit -2 : Conditional EXecution and Iteration

# %%
name = input("Enter name:")
if name == "Priyam":
    print("Hello, Priyam")
else:
    print("Hello Guest")
print("How are you?")
# Out:
# Enter name: Priyam
# Hello, Priyam
# How are you?

# %%
name = input("Enter name:")
if name == "Priyam":
    print("Hello, Priyam")
elif name  == "Priyanka":
    print("Hello,Priyanka")
else:
    print("Hello,Guest")
# Out:
# Enter name: Priyam
# Hello, Priyam

# %%
n1 = int(input("enter no.:"))
n2 = int(input("enter no.:"))
n3 = int(input("enter no.:"))

if n1>n2 and n1>n3:
    print("Biggest No.:",n1)
elif n2>n3:
    print("Biggest No.:",n2)
else:
    print("Biggest No.:",n3)
# Out:
# enter no.: 5
# enter no.: 4
# enter no.: 1
# Biggest No.: 5

# %% [markdown]
# #### Iterative Statements
#
# 1. for
# 2. while

# %%
for i in range(1,6):
    print(i,end = " ")
# Out:
# 1 2 3 4 5

# %%
x = 1
while x<6:
    print(x)
    x+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n = ""
while n!="priyam":
    n = input("enter name:")
    print("incorrect name, please enter correct name")
print("thanks for confirmation")
# Out:
# enter name: psf
# incorrect name, please enter correct name
# enter name: faf
# incorrect name, please enter correct name
# enter name: priyam
# incorrect name, please enter correct name
# thanks for confirmation

# %% [markdown]
# ##### Nested Loops

# %%
for i in range(3):
    for j in range(3):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %% [markdown]
# ##### Loops with Else

# %%
n = [1,2,3,4,5]
for i in n:
    if i==3:
        print("Hello")
        break
    print(i)
else:
    print("Loop completed without finding a specific condition")
# Out:
# 1
# 2
# Hello

# %%
x = 1
while x<=6:
    print(x)
    x+=1
else:
    print("YO")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# YO

# %%
x = 1
while x<=6:
    print(x)
    if x==3:
        break
    x+=1
else:
    print("Hello")
# Out:
# 1
# 2
# 3

# %% [markdown]
# ###### break

# %%
for i in range(10):
    if i==7:
        print("Loop Break")
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Loop Break

# %% [markdown]
# ###### continue

# %%
for i in range(10):
    if i==7:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 8
# 9

# %% [markdown]
# ###### pass

# %%
for i in range(20):
    if i%9==0:
        print(i)
    else:
        pass
# Out:
# 0
# 9
# 18

# %%
# w.a.p. to perform arithmatic operations according to the numbers and sign given by user
n1 = int(input("enter 1st number:"))
n2 = int(input("enter 2nd number:"))
choice = input("enter choice(+,-,*,/,%,**,//):")
if choice=='+':
    print("sum:",n1+n2)
elif choice=='-':
    print("difference:",n1-n2)
elif choice=='*':
    print("product:",n1*n2)
elif choice=='/':
    print("division:",n1/n2)
elif choice=='%':
    print("modulo:",n1%n2)
elif choice=='**':
    print("answer",n1**n2)
elif choice=='//':
    print("floor division:",n1//n2)
else:
    print("invalid choice")
# Out:
# enter 1st number: 1
# enter 2nd number: 2
# enter choice(+,-,*,/,%,**,//): *
# product: 2

# %%
# w.a.p. to calculate the attendance if the attendance is less than 70 % then message should be displayed u r not elgible 
# for bonus marks and if attendance is above 70 then message should be displayed u r eligible for bonus marks and bonus marks are 15% 
# of the attendance
# user input will be total days and absent days 

td = int(input("enter total days:"))
ad = int(input("enter absent days:"))
pd = td-ad
attendance = (pd/td)*100
bm = attendance*0.15
if attendance>=70:
    print("You are eligible for bonus marks")
    print("Bonus marks:",bm)
else:
    print("You are not eligible for bonus marks")
# Out:
# enter total days: 5
# enter absent days: 3
# You are not eligible for bonus marks

# %%
#w.a.p. to calculate the electricity bill when the units is entered by user

units = int(input("enter units:"))
bill = 0
if units<=100:
    bill = 0
elif units>100 and units<200:
    bill = (units-100)*5

else:
    bill = (units-200)*10+500
print("Your bill is:Rs.",bill)
# Out:
# enter units: 50
# Your bill is:Rs. 0

# %%
# w.a.p. to check whether a number entered is 3 digit number or not, if the number is 3 digit number then display the middle digit

n = int(input("enter the number:"))
digit_count = 0
temp = n
while n!=0:
    n = n//10
    digit_count+=1
if digit_count==3:
    print("number entered is a 3 digit number")
    print("middle digit is:",((temp//10)%10))
else:
    print("number entered is not a 3 digit number")
# Out:
# enter the number: 321
# number entered is a 3 digit number
# middle digit is: 2

# %%
#w.a.p. to accept age ,gender , and number of days from user and display the total wages according to the given table 

age = int(input("enter age:"))
gender = input("enter gender(M/F):")
days = int(input("enter no. of days:"))
wages = 0
if age>=18 and age<30:
    if gender=='M':
        wages = 700*days
        print("wages : ",wages)
    elif gender=='F':
        wages = 750*days
        print("wages:",wages)
    else: 
        print("invalid choice of gender please enter M or F")
elif age>=30 and age<=40:
    if gender=='M':
        wages = 800*days
        print("wages : ",wages)
    elif gender=='F':
        wages = 850*days
        print("wages:",wages)
    else: 
        print("invalid choice of gender please enter M or F")
else:
    print("enter valid age,please enter age between 18 and 40")
# Out:
# enter age: 19
# enter gender(M/F): F
# enter no. of days: 10
# wages: 7500

# %%
# w.a.p. to calculate sum and average of 1 to n , n is given by user

n = int(input("enter number till u want sum and average:"))
sum = 0
average = 0
for i in range(1,n+1):
    sum +=i
average = (sum/n)
print("sum:",sum)
print("average:",average)
# Out:
# enter number till u want sum and average: 10
# sum: 55
# average: 5.5

# %%
n = int(input("enter number:"))
sum = 0
average = 0
for i in range(n):
    num = int(input(f"enter number {i+1}:"))
    sum +=num
    average = (sum/num)
print("sum:",sum)
print("average:",average)
# Out:
# enter number: 5
# enter number 1: 1
# enter number 2: 2
# enter number 3: 3
# enter number 4: 4
# enter number 5: 5
# sum: 15
# average: 3.0

# %%
n = int(input("enter number u want to print table off:"))
for i in range(1,11):
    print(n ,'*', i ,'=' , (i*n))
# Out:
# enter number u want to print table off: 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
n = int(input("enter number u want factorial off:"))
factorial = 1
for i in range(1,n+1):
    factorial *= i
    if n==1:
        factorial = 1
    elif n==0:
        factorial = 1
print(factorial)
# Out:
# enter number u want factorial off: 5
# 120

# %%
#print fibbonacci upto n 

n= int(input("enter number:"))
a= 0
b = 1
print(a)
print(b)
for i in range(1,n-1):
    c = a+b
    print(c)
    a = b
    b= c
# Out:
# enter number: 8
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
# w.a.p. to find  the reverse number of the number entered by user check if it is palindrome

n= int(input("enter the number:"))
rev = 0
temp = n
while n!=0:
    digit = n %10 
    rev = rev*10+digit
    n = n//10
    if temp==rev:
        print("number is palindrome")
print("reversed  number:",rev)
# Out:
# enter the number: 121
# number is palindrome
# reversed  number: 121

# %%
# w.a.p. when user gives a number and gets result as sum of digits

n= int(input("enter the number:"))
sum = 0
temp = n
while n!=0:
    digit = n %10 
    sum = sum+digit
    n = n//10
    
print(" sum:",sum)
# Out:
# enter the number: 456
#  sum: 15

# %%
#armstrong number

n= int(input("enter the number:"))
rev = 0
temp = n
temp1 = n
l = 0
while temp1!=0:
    temp1= temp1//10
    l+=1
while n!=0:
    digit = n %10 
    rev = rev+(digit**l)
    n = n//10
    if temp==rev:
        print("armstrong number")
    else:
        print("not armstrong")
# Out:
# enter the number: 153
# not armstrong
# not armstrong
# armstrong number

# %%
# w.a.p. to check whther happy or not
count = 0
for n in range(1,101):
    temp = n
    while n!=1 and n!=4:
        sum = 0
        s = str(n)
        for i in s:
            sum = sum+(int(i)**2)
        n = sum
    if n==1:
        print(temp)
        count+= 1
print("count=",count)
# Out:
# 1
# 7
# 10
# 13
# 19
# 23
# 28
# 31
# 32
# 44
# 49
# 68
# 70
# 79
# 82
# 86
# 91
# 94
# 97
# 100
# count= 20

# %% [markdown]
# #### Patterns

# %%
n = int(input("enter rows:"))

for i in range(1,n+1):
    k = 65
    for j in range(1,i+1):
        print(chr(k),end = " ")
        k = k+1
    print()
# Out:
# enter rows: 5
# A
# A B
# A B C
# A B C D
# A B C D E
